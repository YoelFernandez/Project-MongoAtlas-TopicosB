# %% [markdown]
# # Eliminar documentos

# %%
from connect import db
eliminar = db.libros

#Delete one
res = eliminar.delete_one({"titulo":"1984"})
print("Libro eliminado:", res.deleted_count)
# Out:
# Libro eliminado: 1

# %%
for doc in eliminar.find():
    print(doc)
# Out:
# {'_id': ObjectId('690e123350327f25b273a34b'), 'titulo': 'La ciudad Verde', 'autor': 'Mario Vargas Llosa', 'anio': 1965, 'categoria': ['Novela', 'Peruana'], 'stock': 30, 'disponible': True}
# {'_id': ObjectId('690e148050327f25b273a34c'), 'titulo': 'La ciudad y los perros', 'autor': 'Mario Vargas Llosa', 'anio': 1963, 'categoria': ['Novela', 'Peruana'], 'stock': 4, 'disponible': True}
# {'_id': ObjectId('690e148050327f25b273a34d'), 'titulo': 'Don Quijote de la Mancha', 'autor': 'Miguel de Cervantes', 'anio': 1963, 'categoria': ['Novela', 'Española'], 'stock': 1, 'disponible': True}
# {'_id': ObjectId('690e15e150327f25b273a34f'), 'titulo': 'Fahrenheit 451', 'autor': 'Ray Bradbury', 'anio': 1953, 'generos': ['ciencia ficción', 'distopía'], 'prestado': False, 'editorial': {'nombre': 'Ballantine Books', 'pais': 'EE.UU.'}, 'disponible': True}
# ...
